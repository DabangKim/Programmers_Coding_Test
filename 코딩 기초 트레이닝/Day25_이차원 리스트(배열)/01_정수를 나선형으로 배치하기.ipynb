# %%
def solution(n):
    answer = [[]]
    return answer

# %%
n = int(input())

# %%
n = 3

# %%
answer = []
for i in range(n):
    temp = []
    for j in range(n):
        temp.append(0)
    answer.append(temp)
answer
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %%
n = int(input())
if n%2:
    temp = [1]
    for i in range(int(n/2)):
        temp.append(8*(i+1))
else:
    temp = []
    for i in range(int(n/2)):
        temp.append(i*8 + 4)
temp.reverse()
# Out:
# 4
# [4, 12]

# %%
n = 6
answer = []
for i in range(n):
    temp = []
    for j in range(n):
        temp.append(0)
    answer.append(temp)

# %%
for i in range(n):
    answer[0][i] = i+1
for i in range(n):
    answer[i][n-1] = i+n
for i in range(n-1):
    answer[n-1][n-2-i] = 2*n+i
for i in range(n-1):
    answer[n-1-i][0] = 3*n-2+i
answer
# Out:
# [[1, 2, 3, 4, 5, 6],
#  [20, 0, 0, 0, 0, 7],
#  [19, 0, 0, 0, 0, 8],
#  [18, 0, 0, 0, 0, 9],
#  [17, 0, 0, 0, 0, 10],
#  [16, 15, 14, 13, 12, 11]]
