# %%
def solution(arr):
    i = 0
    while pow(2,i) < len(arr):
        i += 1
    for num in range(pow(2,i)-len(arr)):
        arr.append(0)
    return arr

# %%
def solution(arr):
    a = 1
    b = len(arr)
    while a < b :
        a *= 2
    return arr + [0] * (a-b)
