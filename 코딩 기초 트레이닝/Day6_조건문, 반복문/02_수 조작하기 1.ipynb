# %%
def solution(n, control):
    answer = 0
    w = control.count('w')
    s = control.count('s')
    a = control.count('a')
    d = control.count('d')
    return n + w - s + 10*d - 10*a

solution(0, "wsdawsdassw")
# Out:
# -1

# %%
def solution(n, control):
    answer = n
    c = { 'w':1, 's':-1, 'd':10, 'a':-10}
    for i in control:
        answer += c[i]
    return answer
