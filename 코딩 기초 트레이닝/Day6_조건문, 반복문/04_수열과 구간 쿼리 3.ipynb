# %%
def solution(arr, queries):
    for i in queries:
        num_1 = i[0]
        num_2 = i[1]
        arr[num_1], arr[num_2] = arr[num_2], arr[num_1]

    return arr

# %%
def solution(arr, queries):
    for a,b in queries:
        arr[a],arr[b]=arr[b],arr[a]
    return arr
# Out:
# [3, 4, 1, 0, 2]
