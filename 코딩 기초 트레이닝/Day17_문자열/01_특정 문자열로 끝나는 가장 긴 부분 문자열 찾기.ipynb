# %%
def solution(myString, pat):
    reverse_1 = myString[::-1]
    reverse_2 = pat[::-1]
    find = reverse_1[reverse_1.find(reverse_2):]
    return find[::-1]

# %%
solution=lambda x,y:x[:x.rindex(y)+len(y)]
