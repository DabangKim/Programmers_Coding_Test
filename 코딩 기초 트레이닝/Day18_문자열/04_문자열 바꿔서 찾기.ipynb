# %%
def solution(myString,pat):
    word = ''
    for a in myString:
        if a == 'A':
            word += 'B'
        elif a == 'B':
            word += 'A'
        else:
            word += a
    if pat in word:
        return 1
    else:
        return 0

# %%
def solution(myString, pat):
    return int(pat in myString.replace('A', 'C').replace('B', 'A').replace('C', 'B'))
