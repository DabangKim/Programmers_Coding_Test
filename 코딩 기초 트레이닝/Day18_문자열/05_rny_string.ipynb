# %%
def solution(rny_string):
    result = ''
    for w in rny_string:
        if w == 'm':
            result += 'rn'
        else:
            result += w
    return result

# %%
def solution(rny_string):
    return rny_string.replace('m', 'rn')
