# %%
def solution(n):
    answer = []
    for i in range(n):
        temp = []
        for num in range(n):
            temp.append(0)
        temp[i] = 1
        answer.append(temp)
    return answer

# %%
def solution(n):
    answer=[[0]*n for i in range(n)]
    for i in range(n): answer[i][i]=1
    return answer
