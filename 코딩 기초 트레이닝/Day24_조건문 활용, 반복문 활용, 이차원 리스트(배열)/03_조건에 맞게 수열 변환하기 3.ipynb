# %%
def solution(arr, k):
    if k % 2:
        for i in range(len(arr)):
            arr[i] *= 3
    else:
        for i in range(len(arr)):
            arr[i] += 3
    return arr

# %%
def solution(arr, k):
    return [i*k if k%2!=0 else i+k for i in arr]
