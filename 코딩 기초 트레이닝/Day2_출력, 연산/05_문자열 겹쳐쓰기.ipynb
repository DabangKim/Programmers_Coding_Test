# %%
def solution(my_string, overwrite_string, s):
    first = my_string[0:s]
    length = len(overwrite_string)
    second = my_string[s + length:]
    answer = first + overwrite_string + second
    return answer

solution("Program29b8UYP", "merS123", 7)
# Out:
# 'ProgrammerS123'
