# %%
def solution(arr, k):
    answer = []

    for i in arr:
        if i in answer:
            pass
        else:
            answer.append(i)

    if len(answer) < k:
        for num in range(k - len(answer)):
            answer.append(-1)
    elif len(answer) > k:
        for num in range(len(answer)-k):
            answer.pop()

    return answer

# %%
def solution(arr, k):
    ret = []
    for i in arr:
        if i not in ret:
            ret.append(i)
        if len(ret) == k:
            break

    return ret + [-1] * (k - len(ret))
