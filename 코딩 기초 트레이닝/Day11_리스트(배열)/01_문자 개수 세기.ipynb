# %%
def solution(my_string):
    answer = []
    answer.append(my_string.count("A")) if my_string.count("A") else answer.append(0)
    answer.append(my_string.count("B")) if my_string.count("B") else answer.append(0)
    answer.append(my_string.count("C")) if my_string.count("C") else answer.append(0)
    answer.append(my_string.count("D")) if my_string.count("D") else answer.append(0)
    answer.append(my_string.count("E")) if my_string.count("E") else answer.append(0)
    answer.append(my_string.count("F")) if my_string.count("F") else answer.append(0)
    answer.append(my_string.count("G")) if my_string.count("G") else answer.append(0)
    answer.append(my_string.count("H")) if my_string.count("H") else answer.append(0)
    answer.append(my_string.count("I")) if my_string.count("I") else answer.append(0)
    answer.append(my_string.count("J")) if my_string.count("J") else answer.append(0)
    answer.append(my_string.count("K")) if my_string.count("K") else answer.append(0)
    answer.append(my_string.count("L")) if my_string.count("L") else answer.append(0)
    answer.append(my_string.count("M")) if my_string.count("M") else answer.append(0)
    answer.append(my_string.count("N")) if my_string.count("N") else answer.append(0)
    answer.append(my_string.count("O")) if my_string.count("O") else answer.append(0)
    answer.append(my_string.count("P")) if my_string.count("P") else answer.append(0)
    answer.append(my_string.count("Q")) if my_string.count("Q") else answer.append(0)
    answer.append(my_string.count("R")) if my_string.count("R") else answer.append(0)
    answer.append(my_string.count("S")) if my_string.count("S") else answer.append(0)
    answer.append(my_string.count("T")) if my_string.count("T") else answer.append(0)
    answer.append(my_string.count("U")) if my_string.count("U") else answer.append(0)
    answer.append(my_string.count("V")) if my_string.count("V") else answer.append(0)
    answer.append(my_string.count("W")) if my_string.count("W") else answer.append(0)
    answer.append(my_string.count("X")) if my_string.count("X") else answer.append(0)
    answer.append(my_string.count("Y")) if my_string.count("Y") else answer.append(0)
    answer.append(my_string.count("Z")) if my_string.count("Z") else answer.append(0)
    answer.append(my_string.count("a")) if my_string.count("a") else answer.append(0)
    answer.append(my_string.count("b")) if my_string.count("b") else answer.append(0)
    answer.append(my_string.count("c")) if my_string.count("c") else answer.append(0)
    answer.append(my_string.count("d")) if my_string.count("d") else answer.append(0)
    answer.append(my_string.count("e")) if my_string.count("e") else answer.append(0)
    answer.append(my_string.count("f")) if my_string.count("f") else answer.append(0)
    answer.append(my_string.count("g")) if my_string.count("g") else answer.append(0)
    answer.append(my_string.count("h")) if my_string.count("h") else answer.append(0)
    answer.append(my_string.count("i")) if my_string.count("i") else answer.append(0)
    answer.append(my_string.count("j")) if my_string.count("j") else answer.append(0)
    answer.append(my_string.count("k")) if my_string.count("k") else answer.append(0)
    answer.append(my_string.count("l")) if my_string.count("l") else answer.append(0)
    answer.append(my_string.count("m")) if my_string.count("m") else answer.append(0)
    answer.append(my_string.count("n")) if my_string.count("n") else answer.append(0)
    answer.append(my_string.count("o")) if my_string.count("o") else answer.append(0)
    answer.append(my_string.count("p")) if my_string.count("p") else answer.append(0)
    answer.append(my_string.count("q")) if my_string.count("q") else answer.append(0)
    answer.append(my_string.count("r")) if my_string.count("r") else answer.append(0)
    answer.append(my_string.count("s")) if my_string.count("s") else answer.append(0)
    answer.append(my_string.count("t")) if my_string.count("t") else answer.append(0)
    answer.append(my_string.count("u")) if my_string.count("u") else answer.append(0)
    answer.append(my_string.count("v")) if my_string.count("v") else answer.append(0)
    answer.append(my_string.count("w")) if my_string.count("w") else answer.append(0)
    answer.append(my_string.count("x")) if my_string.count("x") else answer.append(0)
    answer.append(my_string.count("y")) if my_string.count("y") else answer.append(0)
    answer.append(my_string.count("z")) if my_string.count("z") else answer.append(0)
    return answer

# %%
def solution(my_string):
    answer=[0]*52
    for x in my_string:
        if x.isupper():             # str.isupper(): 문자열이 대문자인지 확인
            answer[ord(x)-65]+=1    # ord() : 하나의 문자를 인자로 받고 해당 문자에 해당하는 유니코드 정수를 반환
        else:
            answer[ord(x)-71]+=1
    return answer
