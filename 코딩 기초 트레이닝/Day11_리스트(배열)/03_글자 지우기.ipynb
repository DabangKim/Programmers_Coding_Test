# %%
def solution(my_string, indices):
    list = []
    answer = ''
    for num in range(len(my_string)):
        if num not in indices:
            list.append(num)
    for i in list:
        answer += my_string[i]
    return answer
