# %%
def solution(myString):
    answerString = ''
    for cha in myString:
        if cha == 'a':
            answerString += cha.upper()
        elif cha == 'A':
            answerString += cha
        else:
            answerString += cha.lower()
    return answerString

# %%
def solution(myString):
    return myString.lower().replace('a', 'A')
