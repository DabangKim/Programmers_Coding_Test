# %%
def solution(a, b, flag):
    if flag == True:
        answer = a + b
    else:
        answer = a - b
    return answer

solution(-4, 7, False)
# Out:
# -11

# %%
def solution(a, b, flag):
    if flag: return a+b
    return a-b
