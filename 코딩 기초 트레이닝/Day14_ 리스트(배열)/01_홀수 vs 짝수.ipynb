# %%
def solution(num_list):
    odd = sum(num_list[::2])
    even = sum(num_list[1::2])
    if odd > even:
        return odd
    else:
        return even

# %%
def solution(num_list):
    return max(sum(num_list[::2]), sum(num_list[1::2]))
