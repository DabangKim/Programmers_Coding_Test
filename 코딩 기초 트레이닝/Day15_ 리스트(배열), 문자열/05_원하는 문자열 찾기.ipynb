# %%
def solution(myString, pat):
    first = myString.lower()
    second = pat.lower()
    if second in first:
        return 1
    else:
        return 0

# %%
def solution(myString, pat):
    return int(pat.lower() in myString.lower())
