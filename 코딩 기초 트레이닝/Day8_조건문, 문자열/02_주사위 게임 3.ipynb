# %%
def solution(a, b, c, d):
    answer = 0

    if a == b == c == d:
        answer = 1111 * a

    elif a == b == c != d:
        answer = (10 * a + d)**2
    elif a == b == d != c:
        answer = (10 * a + c)**2
    elif a == c == d != b:
        answer = (10 * a + b)**2
    elif b == c == d != a:
        answer = (10 * b + a)**2

    elif a == b != c == d:
        answer = (a + c) * abs(a - c)
    elif a == c != b == d:
        answer = (a + b) * abs(a - b)
    elif a == d != b == c:
        answer = (a + b) * abs(a - b)

    elif a == b != c != d:
        answer = c * d
    elif a == c != b != d:
        answer = b * d
    elif a == d != b != c:
        answer = b * c
    elif b == c != a != d:
        answer = a * d
    elif b == d != a != c:
        answer = a * c
    elif c == d != a != b:
        answer = a * b

    else:
        answer = min([a, b, c, d])

    return answer

# %%
def solution(a, b, c, d):
    l = sorted([a, b, c, d])
    answer = a * 1111 if l[0] == l[-1] else (10 * l[0] + l[3]) ** 2 if l[0] == l[-2] else (10 * l[-1] + l[0]) ** 2 if l[1] == l[-1] else (l[0] + l[-1]) * abs(l[0] - l[-1]) if l[0] == l[1] and l[2] == l[3] else min(l) if len(set(l)) == 4 else a * b * c * d // next(filter(lambda x: [a, b, c, d].count(x) == 2, l)) ** 2
    return answer
