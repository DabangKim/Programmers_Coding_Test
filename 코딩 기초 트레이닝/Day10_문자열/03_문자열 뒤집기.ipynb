# %%
def solution(my_string, s, e):
    change = my_string[s:e+1]
    change = change[::-1]
    return my_string[:s] + change + my_string[e+1:]

# %%
def solution(my_string, s, e):
    return my_string[:s]+my_string[s:e+1][::-1]+my_string[e+1:]
