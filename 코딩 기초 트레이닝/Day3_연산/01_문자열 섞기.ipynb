# %%
def solution(str1, str2):
    n = 0
    word = ''
    while n < len(str1):
        word_n = str1[n] + str2[n]
        word += word_n
        n += 1

    return word

solution('ccc', 'ddd')
# Out:
# 'cdcdcd'
