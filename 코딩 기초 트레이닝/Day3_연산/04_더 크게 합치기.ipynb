# %%
def solution(a, b):
    num_1 = int(str(a) + str(b))
    num_2 = int(str(b) + str(a))

    if num_1 >= num_2:
        answer = num_1
    else:
        answer = num_2

    return answer

solution(89, 8)
# Out:
# 898

# %%
def solution(a, b):
    return int(max(f"{a}{b}", f"{b}{a}"))
