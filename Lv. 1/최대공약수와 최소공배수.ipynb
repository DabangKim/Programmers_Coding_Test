# %%
def solution(n, m):
    GCD = []
    for i in range(1, min(n, m)+1):
        if n % i == 0 and m % i == 0:
            GCD.append(i)
    if GCD == [1]:
        LCM = n * m
    else:
        LCM = max(GCD) * (n // max(GCD)) * (m // max(GCD))
    return [max(GCD), LCM]
