# %%
def solution(sizes):
    width = max(sizes[0])
    length = min(sizes[0])
    for size in sizes:
        if max(size) > width:
            width = max(size)
        if min(size) > length:
            length = min(size)
    return width * length

# %%
def solution(sizes):
    return max(max(x) for x in sizes) * max(min(x) for x in sizes)
