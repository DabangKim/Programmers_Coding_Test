# %%
def solution(nums):
    nums_diff = list(set(nums))  # 안 겹치는 폰켓몬의 종류
    if len(nums_diff) >= len(nums) // 2:
        return len(nums) // 2
    else:
        return len(nums_diff)

# %%
def solution(ls):
    return min(len(ls)/2, len(set(ls)))
