# %%
def solution(s):
    eng = ['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
    eng_list = list(enumerate(eng))
    for i, j in eng_list:
        if j in s:
            s = s.replace(j, str(i))
    return int(s)
