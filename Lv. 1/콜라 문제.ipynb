# %%
def solution(a, b, n):
    total = 0

    while n >= a:
        remaining = n % a
        received = (n // a) * b
        total += received
        n = remaining + received

    return total

# %%
solution = lambda a, b, n: max(n - b, 0) // (a - b) * b
