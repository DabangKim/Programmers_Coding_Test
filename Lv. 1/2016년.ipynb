# %%
def solution(a, b):
    day = ['THU', 'FRI', 'SAT', 'SUN', 'MON', 'TUE', 'WED']
    if a == 1:
        return day[b%7]
    elif a == 2:
        return day[(31+b)%7]
    elif a == 3:
        return day[(31+29+b)%7]
    elif a == 4:
        return day[(31+29+31+b)%7]
    elif a == 5:
        return day[(31+29+31+30+b)%7]
    elif a == 6:
        return day[(31+29+31+30+31+b)%7]
    elif a == 7:
        return day[(31+29+31+30+31+30+b)%7]
    elif a == 8:
        return day[(31+29+31+30+31+30+30+b)%7]
    elif a == 9:
        return day[(31+29+31+30+31+30+30+31+b)%7]
    elif a == 10:
        return day[(31+29+31+30+31+30+30+31+30+b)%7]
    elif a == 11:
        return day[(31+29+31+30+31+30+30+31+30+31+b)%7]
    else:
        return day[(31+29+31+30+31+30+30+31+30+31+30+b)%7]

# %%
def solution(a, b):
    day = ['THU', 'FRI', 'SAT', 'SUN', 'MON', 'TUE', 'WED']
    days = [31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
    return day[(sum(days[:a-1]) + b) % 7]
