# %%
def solution(n):
    answer = ''
    temp = [i for i in str(n)]
    for num in sorted(temp, reverse=True):
        answer += num
    return int(answer)

# %%
def solution(n):
    ls = list(str(n))
    ls.sort(reverse = True)
    return int("".join(ls))
