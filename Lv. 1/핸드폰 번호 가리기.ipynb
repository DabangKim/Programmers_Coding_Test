# %%
def solution(phone_number):
    answer = ''
    for i in range(len(phone_number)-4):
        answer += '*'
    for num in phone_number[-4:]:
        answer += num
    return answer

# %%
def hide_numbers(s):
    return "*"*(len(s)-4)+s[-4:]
