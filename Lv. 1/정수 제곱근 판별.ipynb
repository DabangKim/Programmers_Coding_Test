# %%
import math

def solution(n):
    if n / int(math.sqrt(n)) == int(math.sqrt(n)):
        return (int(math.sqrt(n))+1) ** 2
    return -1

# %%
def nextSqure(n):
    sqrt = n ** (1/2)

    if sqrt % 1 == 0:
        return (sqrt + 1) ** 2
    return 'no'
