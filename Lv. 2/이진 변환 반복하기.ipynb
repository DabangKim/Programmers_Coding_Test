# %%
def solution(s):
    trial, num_0 = 0, 0
    while s != '1':
        s_remove_0 = s.replace('0', '')
        num_0 += len(s) - len(s_remove_0)
        s = len(s_remove_0)
        s = format(s, 'b')
        trial += 1
    return [trial, num_0]
