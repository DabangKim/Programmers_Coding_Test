# %%
def solution(n, words):
    stack = [words[0]]
    for i in range(1, len(words)):
        stack.append(words[i])
        if stack.count(words[i]) > 1 or words[i][0] != stack[-2][-1]:
            return [i%n+1, i//n+1]
            break
    return [0,0]
