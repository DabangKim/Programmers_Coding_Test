# %%
def solution(n, left, right):
    arr = []
    for idx in range(left, right + 1):
        row = idx // n
        col = idx % n
        value = max(row, col) + 1
        arr.append(value)
    return arr
