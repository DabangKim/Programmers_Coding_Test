# %%
def solution(s):
    answer = ''
    capitalize = True
    for ch in s:
        if ch == ' ':
            answer += ch
            capitalize = True
        else:
            if capitalize:
                answer += ch.upper()
                capitalize = False
            else:
                answer += ch.lower()
    return answer
