# %%
def solution(sides):
    a = max(sides) - (max(sides) - min(sides) + 1) + 1  # sides에서 가장 긴 변이 있을 경우
    b = (max(sides) + min(sides)) - max(sides) - 1      # 나머지 한 변이 제일 긴 경우
    return a + b

# %%
def solution(sides):
    return 2 * min(sides) - 1
