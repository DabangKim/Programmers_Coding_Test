# %%
def solution(A, B):
    answer = 0
    A = list(A)
    B = list(B)
    while A != B:
        A = list(A[-1]) + A
        A.pop()
        answer += 1
        if answer == len(A):
            answer = -1
            break
    return answer

# %%
solution=lambda a,b:(b*2).find(a)
