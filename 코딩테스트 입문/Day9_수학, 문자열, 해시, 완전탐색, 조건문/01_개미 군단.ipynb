# %%
def solution(hp):
    장군 = hp // 5
    hp = hp % 5
    병정 = hp // 3
    hp = hp % 3
    일 = hp // 1
    hp = hp % 1
    return 장군 + 병정 + 일

# %%
def solution(hp):
    answer = 0
    for ant in [5, 3, 1]:
        d, hp = divmod(hp, ant)
        answer += d
    return answer
