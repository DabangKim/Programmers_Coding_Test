# %%
def divisor(num):
    temp = []
    for i in range(1, num+1):
        if num % i == 0:
            temp.append(i)
    return temp

def solution(n):
    answer = 0
    for i in range(1, n+1):
        if len(divisor(i)) >= 3:
            answer += 1
    return answer
