# %%
def solution(n):
    for i in range(n):
        if i * i == n:
            return 1
    return 2

# %%
def solution(n):
    return 1 if (n ** 0.5).is_integer() else 2

# %%
def solution(n):
    return 1 if (n ** 0.5) % 1 == 0 else 2
