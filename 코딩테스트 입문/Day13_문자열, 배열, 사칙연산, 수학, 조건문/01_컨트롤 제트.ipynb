# %%
def solution(s):
    temp = s.split()
    answer = 0
    for i in range(len(temp)):
        if temp[i] == 'Z':
            answer -= int(temp[i-1])
        else:
            answer += int(temp[i])
    return answer
