# %%
def checker(n):
    temp = []
    for i in range(1, n+1):
        if n % i == 0:
            temp.append(i)
    return temp

def solution(n):
    answer = []
    temp = checker(n)
    for num in temp:
        if len(checker(num)) == 2:
            answer.append(num)
    return answer
