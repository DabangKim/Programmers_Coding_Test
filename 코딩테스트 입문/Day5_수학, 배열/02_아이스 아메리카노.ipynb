# %%
def solution(money):
    n = 0
    while True:
        if money - 5500*(n+1) < 0:
            return (n, money - 5500*n)
        else:
            n += 1

# %%
def solution(money):
    return [money // 5500, money % 5500]

# %%
def solution(money):
    return divmod(money, 5500)
