# %%
def solution(n):
    temp = []
    for i in range(1, n+1):
        if n%i == 0:
            temp.append(i)
    return len(temp)

# %%
def solution(n):
    return sum(n % i == 0 for i in range(1, n+1))
