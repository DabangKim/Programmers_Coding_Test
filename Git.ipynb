# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/프로그래머스 코테
# Out:
# /content/drive/MyDrive/Colab Notebooks/프로그래머스 코테

# %% [markdown]
# ### 1. Git 초기화

# %%
# !git init

# %% [markdown]
# ### 2. 사용자 정보 설정

# %%
# !git config user.name "MinSung"
# !git config user.email "nzkiwiking@gmail.com"

# %% [markdown]
# ### 3. GitHub 원격 저장소 연결(보안 때문에 실행 후 삭제)

# %%
# !git remote add origin https://<username>:<token>@github.com/<username>/<repo>.git

# %% [markdown]
# ### 4. 파일 add 및 commit

# %%
# !git add .
# !git commit -m "코랩에서의 첫 commit"

# %% [markdown]
# ### 5. branch 설정

# %%
# !git branch -M main

# %% [markdown]
# ### 6. push

# %%
# !git push -u origin main

# %% [markdown]
# ### 7. Git 업데이트

# %%
# 토큰 만료 시
# !git remote set-url origin https://<username>:<token>@github.com/<username>/<repo>.git

# %%
# !git add .
# !git commit -m "LV2. 연속 부분 수열 합의 개수 해결"
# !git push
# Out:
# [main c7a5787] LV2. 예상 대진표 해결
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite Git.ipynb (70%)
#  create mode 100644 "Lv. 2/\341\204\213\341\205\250\341\204\211\341\205\241\341\206\274 \341\204\203\341\205\242\341\204\214\341\205\265\341\206\253\341\204\221\341\205\255.ipynb"
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.72 KiB | 293.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/DabangKim/Programmers_Coding_Test
#    686f95e..c7a5787  main -> main
