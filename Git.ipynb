# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/프로그래머스 코테
# Out:
# /content/drive/MyDrive/Colab Notebooks/프로그래머스 코테

# %% [markdown]
# ### 7. Git 업데이트

# %%
# 토큰 만료 시
# !git remote set-url origin https://<username>:<token>@github.com/<username>/<repo>.git

# %%
# !git add .
# !git commit -m "LV2. 피로도 해결"
# !git push
# Out:
# [main caabb87] LV2. 기능개발 해결
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite Git.ipynb (61%)
#  create mode 100644 "Lv. 2/\341\204\200\341\205\265\341\204\202\341\205\263\341\206\274\341\204\200\341\205\242\341\204\207\341\205\241\341\206\257.ipynb"
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.30 KiB | 83.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/DabangKim/Programmers_Coding_Test
#    8f8825a..caabb87  main -> main
