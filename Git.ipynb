# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Colab Notebooks/프로그래머스 코테

# %% [markdown]
# ### 1. Git 초기화

# %%
# !git init

# %% [markdown]
# ### 2. 사용자 정보 설정

# %%
# !git config user.name "MinSung"
# !git config user.email "nzkiwiking@gmail.com"

# %% [markdown]
# ### 3. GitHub 원격 저장소 연결(보안 때문에 실행 후 삭제)

# %%
# !git remote add origin https://<username>:<token>@github.com/<username>/<repo>.git

# %% [markdown]
# ### 4. 파일 add 및 commit

# %%
# !git add .
# !git commit -m "코랩에서의 첫 commit"

# %% [markdown]
# ### 5. branch 설정

# %%
# !git branch -M main

# %% [markdown]
# ### 6. push

# %%
# !git push -u origin main

# %% [markdown]
# ### 7. Git 업데이트

# %%
# 토큰 만료 시
# !git remote set-url origin https://<username>:<token>@github.com/<username>/<repo>.git

# %%
# !git add .
# !git commit -m "LV2. n^2 배열 자르기 해결"
# !git push
# Out:
# [main d31b43f] LV2. 괄호 회전하기 해결
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 "Lv. 2/\341\204\200\341\205\252\341\206\257\341\204\222\341\205\251 \341\204\222\341\205\254\341\204\214\341\205\245\341\206\253\341\204\222\341\205\241\341\204\200\341\205\265.ipynb"
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.62 KiB | 138.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/DabangKim/Programmers_Coding_Test
#    a2f21db..d31b43f  main -> main
